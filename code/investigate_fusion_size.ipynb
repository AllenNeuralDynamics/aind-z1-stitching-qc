# %%
import dask.array as da
import numpy as np
import zarr
from pathlib import Path

# %%
data_loc =Path('/data')
dataset_name = 'HCR_783551_2025-10-08_13-00-00_processed_2025-10-22_17-55-54'
print(f'data location: {data_loc / dataset_name}')
print("---- fused channels ----")
channels = ['405', '488',  '561',  '638']
for ch in channels:
    zarr_path = data_loc / dataset_name / 'image_tile_fusing'/ 'fused'/ f'channel_{ch}.zarr' / '0'
    dask_array = da.from_zarr(str(zarr_path))
    print(f"channel {ch} shape ", dask_array.shape)
# zarr_path = data_loc / dataset_name / 'image_tile_fusing'/ 'fused'/ 'channel_405.zarr' / '0'
# dask_array = da.from_zarr(str(zarr_path))

print("---- segmentation mask ----")
mask_path = data_loc / dataset_name / 'image_tile_fusing'/ 'cell_body_segmentation'/ 'segmentation_mask.zarr' / '0'
mask_array = da.from_zarr(str(mask_path))
print("mask shape ", mask_array.shape)
# print("405 shape ", dask_array.shape)
# Out:
# data location: /data/HCR_783551_2025-10-08_13-00-00_processed_2025-10-22_17-55-54
# ---- fused channels ----
# channel 405 shape  (1, 1, 965, 9252, 9241)
# channel 488 shape  (1, 1, 965, 9252, 9241)
# channel 561 shape  (1, 1, 965, 9252, 9241)
# channel 638 shape  (1, 1, 965, 9252, 9241)
# ---- segmentation mask ----
# mask shape  (1, 1, 965, 9252, 9240)

# %%
import json
from pathlib import Path
from typing import Iterable, Tuple, Union

try:
    import s3fs  # optional; only needed for s3:// sources
except ImportError:  # pragma: no cover
    s3fs = None  # type: ignore


def get_highest_resolution_spacing(
    zarr_root: Union[str, Path]
) -> Tuple[float, float, float]:
    """
    Return the finest-resolution (Z, Y, X) voxel spacing stored in an OME-Zarr.

    Parameters
    ----------
    zarr_root :
        Filesystem path (e.g. ``/data/sample.zarr``) or S3 URI (e.g. ``s3://bucket/sample.zarr``).

    Returns
    -------
    Tuple[float, float, float]
        Spacing in micrometers for the highest-resolution scale level.

    Raises
    ------
    FileNotFoundError
        If the `.zattrs` metadata file cannot be located.
    ValueError
        If the metadata is missing the multiscale definition or spatial scales.
    RuntimeError
        If S3 access is requested but the optional `s3fs` dependency is unavailable.
    """
    zarr_root = Path(zarr_root)
    zattrs_path = zarr_root / ".zattrs"

    if str(zattrs_path).startswith("s3://"):
        if s3fs is None:
            raise RuntimeError("s3fs is required to read s3:// paths")
        fs = s3fs.S3FileSystem()
        with fs.open(str(zattrs_path), "r") as handle:
            zattrs = json.load(handle)
    else:
        with zattrs_path.open("r") as handle:
            zattrs = json.load(handle)

    multiscales: Iterable[dict] = zattrs.get("multiscales", [])
    if not multiscales:
        raise ValueError("OME-Zarr metadata missing 'multiscales' block")

    datasets = multiscales[0].get("datasets", [])
    if not datasets:
        raise ValueError("OME-Zarr metadata missing 'datasets' entries")

    def spatial_scale(dataset: dict) -> Tuple[float, float, float]:
        for transform in dataset.get("coordinateTransformations", []):
            if transform.get("type") == "scale":
                scale = transform.get("scale", [])
                if len(scale) >= 3:
                    # Use the last three entries; OME order is usually (t, c, z, y, x)
                    return tuple(scale[-3:])
        raise ValueError("Dataset is missing a spatial 'scale' transform")

    # Highest resolution corresponds to the smallest spatial scale factors.
    finest = min(datasets, key=lambda ds: spatial_scale(ds))
    return spatial_scale(finest)

# %%
import numpy as np
import zarr
import dask.array as da
from dask.distributed import Client, LocalCluster, performance_report
from dask import delayed
import dask
from multiprocessing import Pool
import s3fs

import numcodecs
from numcodecs import Blosc
from dataclasses import dataclass



@dataclass
class OutputParameters:
    path: str
    chunksize: tuple[int, int, int, int, int]
    resolution_zyx: tuple[float, float, float]
    dtype: np.dtype = np.uint16
    dimension_separator: str = "."
    compressor: numcodecs.blosc.Blosc = None #Blosc(cname='zstd', clevel=1, shuffle=Blosc.SHUFFLE)

def initialize_output_volume(
    output_params: OutputParameters,
    output_volume_size: tuple[int, int, int],
) -> zarr.core.Array:
    """
    Self-documentation of output store initialization.

    Inputs
    ------
    output_params: OutputParameters application instance.
    output_volume_size: output of initalize_data_structures(...)

    Returns
    -------
    Zarr thread-safe datastore initialized on OutputParameters.
    """

    # Local execution
    out_group = zarr.open_group(output_params.path, mode="w")

    # Cloud execuion
    if output_params.path.startswith('s3'):
        s3 = s3fs.S3FileSystem(
            config_kwargs={
                'max_pool_connections': 50,
                's3': {
                'multipart_threshold': 64 * 1024 * 1024,  # 64 MB, avoid multipart upload for small chunks
                'max_concurrent_requests': 20  # Increased from 10 -> 20.
                },
                'retries': {
                'total_max_attempts': 100,
                'mode': 'adaptive',
                }
            }
        )
        store = s3fs.S3Map(root=output_params.path, s3=s3)
        out_group = zarr.open(store=store, mode='a')

    path = "0"
    chunksize = output_params.chunksize
    datatype = output_params.dtype
    dimension_separator = output_params.dimension_separator
    compressor = output_params.compressor
    output_volume = out_group.create_dataset(
        path,
        shape=(
            1,
            1,
            output_volume_size[0],
            output_volume_size[1],
            output_volume_size[2],
        ),
        chunks=chunksize,
        dtype=datatype,
        compressor=compressor,
        dimension_separator=dimension_separator,
        overwrite=True,
        fill_value=0,
    )

    return output_volume



def sum_chunk_data(chunk):
    """
    Sum the data within a given chunk.

    Parameters:
    - chunk: A multidimensional numpy array representing the chunk of data.

    Returns:
    - The sum of all elements within the chunk.
    """
    return chunk.sum().compute()

def process_chunk(params):
    z_idx, y_idx, x_idx, input_zarr, output_zarr, upscale_factors_zyx, current_chunk, total_chunks = params
    # print(f"Upscaling chunk {current_chunk}/{total_chunks}", flush=True)
    if len(input_zarr.shape) == 5: #tczyx
        chunk = input_zarr[0, 0, z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
    elif len(input_zarr.shape) == 3: #zyx
        chunk = input_zarr[z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
    else:
        print("len(input_zarr.shape) not compatible: ", len(input_zarr.shape), 'exiting')
        exit()
    
    # Upscale the chunk by duplicating each value to fill a 4x4x4 block
    upscaled_chunk = np.repeat(np.repeat(np.repeat(chunk, upscale_factors_zyx[0], axis=0), upscale_factors_zyx[1], axis=1), upscale_factors_zyx[2], axis=2)
    
    # Calculate the indices for placing the upscaled chunk in the output
    z_new, y_new, x_new = z_idx * upscale_factors_zyx[0], y_idx * upscale_factors_zyx[1], x_idx * upscale_factors_zyx[2]
    
    output_zarr[0, 0, z_new:z_new+upscaled_chunk.shape[0], y_new:y_new+upscaled_chunk.shape[1], x_new:x_new+upscaled_chunk.shape[2]] = upscaled_chunk.compute()


def upscale_zarr(input_path, output_params, upscale_factors_zyx=(1, 4, 4)):
    """
    Upscale a Zarr volume by a factor of 4 in the spatial dimensions (y, x)
    and save to a new Zarr file. Assumes input is in tczyx format with t and c = 1.

    Parameters:
    - input_path: Path to the input Zarr file.
    - output_path: Path to the output Zarr file.
    """
    # Open the input Zarr file
    input_zarr = da.from_zarr(input_path)
    t = 1
    c = 1
    if len(input_zarr.shape) == 5:
        _, _, z, y, x = input_zarr.shape
    else:
        z, y, x = input_zarr.shape


    # Calculate the shape of the upscaled volume
    new_shape = (t, c, z * upscale_factors_zyx[0], y * upscale_factors_zyx[1], x * upscale_factors_zyx[2])
    

    chunk_size = (1, 1, 128, 128, 128)

    print(f"Upscaling {input_path} from size {input_zarr.shape} by {upscale_factors_zyx} to new shape {new_shape} with {output_params.chunksize} chunk size and dtype: {output_params.dtype} ")

    client = Client(LocalCluster(n_workers=32, threads_per_worker=1, processes=True))

    output_zarr = initialize_output_volume(output_params, new_shape[-3:])

    # Calculate the total number of chunks to process
    total_chunks = (np.ceil(z / 128) * np.ceil(y / 128) * np.ceil(x / 128)).astype(int)
    current_chunk = 1

    # Process and upscale each chunk
    for z_idx in range(0, z, 128):
        for y_idx in range(0, y, 128):
            for x_idx in range(0, x, 128):
                # print(f"Upscaling chunk {current_chunk}/{total_chunks}")
                current_chunk += 1
                # Extract the current chunk
                if len(input_zarr.shape) == 5: #tczyx
                    chunk = input_zarr[0, 0, z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
                elif len(input_zarr.shape) == 3: #zyx
                    chunk = input_zarr[z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
                else:
                    print("len(input_zarr.shape) not compatible: ", len(input_zarr.shape), 'exitting')
                    exit()
                
                # Upscale the chunk by duplicating each value to fill a 4x4x4 block
                upscaled_chunk = np.repeat(np.repeat(np.repeat(chunk, upscale_factors_zyx[0], axis=0), upscale_factors_zyx[1], axis=1), upscale_factors_zyx[2], axis=2)

                #chunk_sum = sum_chunk_data(chunk)
                #upscaled_sum = sum_chunk_data(upscaled_chunk)
                #print("sums:", chunk_sum, upscaled_sum, 'ratio:', upscaled_sum/chunk_sum, "chunk_shape:", chunk.shape, "upscaled_chunk_shape", upscaled_chunk.shape)
                
                # Calculate the indices for placing the upscaled chunk in the output
                z_new, y_new, x_new = z_idx * upscale_factors_zyx[0], y_idx * upscale_factors_zyx[1], x_idx * upscale_factors_zyx[2]

                output_zarr[0, 0, z_new:z_new+upscaled_chunk.shape[0], y_new:y_new+upscaled_chunk.shape[1], x_new:x_new+upscaled_chunk.shape[2]] = upscaled_chunk.compute()

    print("Upscaling completed.")

# %%
def upscale_zarr_to_fixed_shape(input_path, output_params, upscale_factors_zyx=(1, 4, 4), fixed_shape= (None, None, None)):
    """
    Upscale a Zarr volume by a factor of 4 in the spatial dimensions (y, x)
    and save to a new Zarr file. Assumes input is in tczyx format with t and c = 1.

    Parameters:
    - input_path: Path to the input Zarr file.
    - output_path: Path to the output Zarr file.
    """
    # Open the input Zarr file
    input_zarr = da.from_zarr(input_path)
    t = 1
    c = 1
    if len(input_zarr.shape) == 5:
        _, _, z, y, x = input_zarr.shape
    else:
        z, y, x = input_zarr.shape


    # Calculate the shape of the upscaled volume
    new_shape = (t, c, z * upscale_factors_zyx[0], y * upscale_factors_zyx[1], x * upscale_factors_zyx[2])

    if fixed_shape[0] is not None:
        new_shape = (t, c, fixed_shape[0], fixed_shape[1], fixed_shape[2])

    chunk_size = (1, 1, 128, 128, 128)

    print(f"Upscaling {input_path} from size {input_zarr.shape} by {upscale_factors_zyx} to new shape {new_shape} with {output_params.chunksize} chunk size and dtype: {output_params.dtype} ")

    client = Client(LocalCluster(n_workers=32, threads_per_worker=1, processes=True))

    output_zarr = initialize_output_volume(output_params, new_shape[-3:])

    # Calculate the total number of chunks to process
    total_chunks = (np.ceil(z / 128) * np.ceil(y / 128) * np.ceil(x / 128)).astype(int)
    current_chunk = 1

    # Process and upscale each chunk
    for z_idx in range(0, z, 128):
        for y_idx in range(0, y, 128):
            for x_idx in range(0, x, 128):
                # print(f"Upscaling chunk {current_chunk}/{total_chunks}")
                current_chunk += 1
                # Extract the current chunk
                if len(input_zarr.shape) == 5: #tczyx
                    chunk = input_zarr[0, 0, z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
                elif len(input_zarr.shape) == 3: #zyx
                    chunk = input_zarr[z_idx:z_idx+128, y_idx:y_idx+128, x_idx:x_idx+128]
                else:
                    print("len(input_zarr.shape) not compatible: ", len(input_zarr.shape), 'exitting')
                    exit()
                
                # Upscale the chunk by duplicating each value to fill a 4x4x4 block
                upscaled_chunk = np.repeat(np.repeat(np.repeat(chunk, upscale_factors_zyx[0], axis=0), upscale_factors_zyx[1], axis=1), upscale_factors_zyx[2], axis=2)

                #chunk_sum = sum_chunk_data(chunk)
                #upscaled_sum = sum_chunk_data(upscaled_chunk)
                #print("sums:", chunk_sum, upscaled_sum, 'ratio:', upscaled_sum/chunk_sum, "chunk_shape:", chunk.shape, "upscaled_chunk_shape", upscaled_chunk.shape)
                
                # Calculate the indices for placing the upscaled chunk in the output
                z_new, y_new, x_new = z_idx * upscale_factors_zyx[0], y_idx * upscale_factors_zyx[1], x_idx * upscale_factors_zyx[2]

                output_zarr[0, 0, z_new:z_new+upscaled_chunk.shape[0], y_new:y_new+upscaled_chunk.shape[1], x_new:x_new+upscaled_chunk.shape[2]] = upscaled_chunk.compute()

    print("Upscaling completed.")

# %%
zarr_path = data_loc / dataset_name / 'image_tile_fusing'/ 'fused'/ f'channel_{ch}.zarr'
full_scale_voxel_spacing_zyx = get_highest_resolution_spacing(zarr_path)
print("full scale voxel spacing (zyx): ", full_scale_voxel_spacing_zyx)
# Out:
# full scale voxel spacing (zyx):  (1.0, 1.0, 1.0)

# %%
#let's try upscaling the segmentation mask to match the fused channel sizes 
full_res_shape = dask_array.shape  # shape of the fused channels

mask_path = data_loc / dataset_name / 'image_tile_fusing'/ 'cell_body_segmentation'/ 'segmentation_mask_orig_res.zarr' / '0'
mask_array = da.from_zarr(str(mask_path))
print("mask shape ", mask_array.shape)
fixed_shape = (full_res_shape[2], full_res_shape[3], full_res_shape[4])
print("fixed shape for upscaling: ", fixed_shape)


test_path = '/scratch/output_segmentation_mask_test.zarr'
compressor = Blosc(cname='zstd', clevel=1, shuffle=Blosc.SHUFFLE)
upload_params = OutputParameters(
    chunksize=(1,1,128,128,128),
    resolution_zyx=full_scale_voxel_spacing_zyx, 
    dtype=np.uint16, 
    path=test_path, 
    compressor=compressor)

upscale_zarr_to_fixed_shape(mask_path, upload_params, upscale_factors_zyx=(1, 4, 4), fixed_shape= fixed_shape)
# Out:
# mask shape  (1, 1, 965, 2313, 2310)
# fixed shape for upscaling:  (965, 9252, 9241)
# Upscaling /data/HCR_783551_2025-10-08_13-00-00_processed_2025-10-22_17-55-54/image_tile_fusing/cell_body_segmentation/segmentation_mask_orig_res.zarr/0 from size (1, 1, 965, 2313, 2310) by (1, 4, 4) to new shape (1, 1, 965, 9252, 9241) with (1, 1, 128, 128, 128) chunk size and dtype: <class 'numpy.uint16'>
# 2025-10-30 18:26:39,225 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 377.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:26,537 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.62 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:26,729 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 259.60 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:27,791 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.72 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:27,930 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 259.69 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:29,233 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.75 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:29,538 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 259.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:31,733 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.80 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:32,029 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 259.77 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:33,354 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.86 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:33,530 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 259.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:34,230 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.22 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:34,429 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.20 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:35,983 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:36,113 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.31 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:37,729 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.41 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:37,833 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.39 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:38,631 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.95 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:38,929 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:39,631 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:39,929 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.52 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:40,753 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:40,929 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:41,630 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.14 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:41,929 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:42,680 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 388.20 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:43,029 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.69 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:44,630 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.60 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:45,032 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 260.72 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:47,330 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 389.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:47,463 - distributed.worker.memory - WARNING - Worker is at 59% memory usage. Resuming worker. Process memory: 290.25 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:48,231 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 389.80 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:48,530 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 261.77 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:49,430 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 389.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:49,729 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.17 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:51,987 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.37 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:52,272 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:53,030 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:53,329 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.36 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:54,730 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 389.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:55,029 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:55,730 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.28 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:56,030 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.51 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:57,431 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:28:57,629 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:02,343 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.97 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:02,529 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 262.94 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:03,930 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:04,230 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.02 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:05,243 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.15 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:05,429 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:06,131 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:06,429 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:07,830 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:08,029 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:08,729 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.86 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:09,029 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.35 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:14,230 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:14,729 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.69 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:15,429 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:15,730 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.79 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:16,936 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.35 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:17,229 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.84 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:19,830 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.70 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:20,129 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 263.93 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:21,530 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 391.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:21,830 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 264.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:23,429 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 392.24 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:23,533 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 306.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:25,130 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 392.37 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:25,429 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 264.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:26,143 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.43 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:26,329 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 264.40 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:30,779 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.76 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:30,903 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 307.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:32,430 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 392.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:32,730 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 264.79 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:34,830 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.42 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:35,130 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 264.90 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:36,730 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.77 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:37,029 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.00 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:37,976 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.14 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:38,103 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 308.12 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:38,930 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.91 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:39,230 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.15 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:41,330 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.79 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:41,559 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.28 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:43,030 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 392.14 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:43,245 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.40 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:43,930 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 392.99 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:44,229 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.47 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:45,763 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:45,929 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.54 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:48,130 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:48,233 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 308.36 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:49,930 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.35 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:50,230 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.84 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:50,929 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.93 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:51,033 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 308.23 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:51,979 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:52,229 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 265.94 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:53,930 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:54,229 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 266.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:55,630 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.65 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:55,929 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 266.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:57,330 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.32 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:57,443 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 308.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:58,230 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 393.27 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:29:58,529 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 266.37 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:00,729 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.50 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:00,833 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 309.48 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:02,633 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:02,830 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 266.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:03,530 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:03,730 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 266.65 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:05,230 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.60 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:05,550 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 266.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:10,230 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 395.15 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:10,529 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 267.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:11,930 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 394.13 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:12,130 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 267.23 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:15,985 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 395.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:16,229 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 267.54 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:17,729 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:17,854 - distributed.worker.memory - WARNING - Worker is at 61% memory usage. Resuming worker. Process memory: 296.05 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:19,452 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:19,629 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 268.25 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:20,463 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:20,652 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 268.30 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:21,429 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:21,554 - distributed.worker.memory - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 311.02 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:25,093 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:25,349 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 268.65 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:26,030 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.20 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:26,329 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 268.69 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:27,730 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.80 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:28,029 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 268.78 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:31,730 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 395.95 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:32,029 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.06 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:34,986 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:35,229 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.31 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:36,030 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.58 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:36,329 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.32 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:37,830 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.93 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:38,052 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.42 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:38,843 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.51 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:39,029 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.48 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:39,730 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:39,853 - distributed.worker.memory - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 312.22 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:40,930 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.46 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:41,230 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 269.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:42,107 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:42,229 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 270.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:43,630 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:43,930 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 270.06 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:45,330 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.67 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:45,629 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 270.15 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:49,330 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.97 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:49,629 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 270.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:51,193 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:51,334 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 270.56 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:52,830 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:52,943 - distributed.worker.memory - WARNING - Worker is at 61% memory usage. Resuming worker. Process memory: 299.51 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:53,829 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.70 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:53,972 - distributed.worker.memory - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 313.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:56,329 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:56,443 - distributed.worker.memory - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 313.87 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:58,230 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:58,449 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 271.05 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:59,130 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 397.85 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:30:59,434 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 271.12 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:00,130 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 387.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:00,429 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 271.15 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:01,963 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.30 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:02,129 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 271.27 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:03,631 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:03,929 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:05,330 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.21 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:05,629 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.48 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:07,130 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 396.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:07,429 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:08,130 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:08,352 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.65 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:09,153 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:09,330 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:10,931 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.90 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:11,229 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 271.88 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:13,730 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:14,029 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:15,486 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.92 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:15,733 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:16,430 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.95 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:16,730 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.23 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:17,431 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.28 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:17,729 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.25 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:18,430 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:18,729 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.31 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:20,130 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.91 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:20,429 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.41 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:21,830 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:22,129 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.52 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:23,003 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.63 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:23,130 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:24,530 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.17 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:24,829 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.66 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:25,654 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:25,829 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:28,829 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.97 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:29,129 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 272.94 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:30,030 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:30,329 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:31,030 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:31,335 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.12 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:32,131 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:32,429 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:34,930 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.98 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:35,329 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.25 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:36,630 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 400.09 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:36,929 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.36 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:37,629 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.44 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:37,929 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.41 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:38,629 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.49 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:38,930 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.46 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:41,209 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:41,333 - distributed.worker.memory - WARNING - Worker is at 65% memory usage. Resuming worker. Process memory: 316.33 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:43,631 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.30 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:43,823 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 401.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:43,830 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.79 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:44,762 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.88 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:44,929 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.85 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:46,330 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 398.41 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:46,629 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 273.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:53,951 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 401.83 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:54,729 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.09 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:58,730 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 395.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:31:59,030 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.26 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:00,530 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 402.84 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:00,830 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.32 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:02,335 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.46 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:02,529 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.43 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:05,772 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.67 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:05,929 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:07,530 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.21 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:07,829 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.70 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:09,329 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.81 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:09,630 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.78 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:11,230 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.42 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:11,530 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.90 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:12,930 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 402.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:13,230 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 275.99 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:13,930 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 402.77 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:14,129 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 276.03 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:16,497 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 402.90 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:16,750 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.17 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:18,329 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.27 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:18,435 - distributed.worker.memory - WARNING - Worker is at 65% memory usage. Resuming worker. Process memory: 318.58 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:21,830 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.95 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:22,129 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.44 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:22,930 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.02 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:23,229 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.52 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:24,730 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 403.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:25,029 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.63 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:25,852 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:26,029 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:26,730 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 399.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:27,030 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.72 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:28,829 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.87 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:28,953 - distributed.worker.memory - WARNING - Worker is at 65% memory usage. Resuming worker. Process memory: 318.85 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:30,762 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.99 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:30,930 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 276.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 18:32:34,031 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 404.10 MiB -- Worker memory limit: 484.47 MiB
# ...
# 2025-10-30 19:03:34,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 300.92 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:35,633 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 413.53 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:35,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 300.98 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:36,533 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 428.03 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:36,749 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.03 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:37,433 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 428.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:37,732 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:38,612 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.21 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:38,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.19 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:39,533 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:39,833 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.26 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:40,631 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.36 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:40,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:47,530 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 428.58 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:47,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.84 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:48,633 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.93 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:48,933 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 301.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:50,662 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 430.03 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:50,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.00 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:51,533 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 428.81 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:51,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:53,232 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 428.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:53,532 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:54,932 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.03 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:55,232 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.28 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:55,932 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 416.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:56,232 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.34 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:56,933 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.92 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:57,232 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.41 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:58,732 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 395.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:03:59,032 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:01,622 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 430.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:01,743 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.70 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:04,264 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 430.86 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:04,432 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.82 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:05,233 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 429.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:05,532 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.87 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:07,293 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 431.00 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:07,432 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 302.97 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:09,843 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:10,032 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.16 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:11,632 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.33 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:11,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.31 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:12,633 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 430.89 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:12,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.38 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:13,633 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 430.96 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:13,931 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:14,632 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 402.07 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:15,033 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.52 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:18,355 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.71 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:18,532 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.68 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:21,131 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.94 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:21,432 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.91 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:22,233 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:22,532 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 303.95 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:25,832 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.23 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:25,964 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 346.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:27,533 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.29 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:27,832 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 304.30 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:28,731 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.88 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:29,032 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 304.37 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:29,733 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 431.18 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:30,132 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 304.44 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:31,632 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 425.04 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:31,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 304.49 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:34,333 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:34,633 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 304.61 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:36,232 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.75 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:36,354 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 347.73 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:38,732 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.94 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:38,864 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 346.91 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:41,632 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.63 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:41,932 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 305.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:44,246 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 423.86 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:44,532 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.32 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:45,231 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 433.37 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:45,363 - distributed.worker.memory - WARNING - Worker is at 71% memory usage. Resuming worker. Process memory: 348.35 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:47,655 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 433.47 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:47,831 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.43 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:49,433 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 433.54 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:49,732 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.51 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:50,432 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.55 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:50,731 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.57 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:51,432 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 390.11 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:51,732 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.64 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:53,382 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 433.79 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:53,532 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.77 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:54,233 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 432.59 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:54,532 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.86 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:55,233 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 433.45 MiB -- Worker memory limit: 484.47 MiB
# 2025-10-30 19:04:55,531 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 305.95 MiB -- Worker memory limit: 484.47 MiB
# Upscaling completed.

# %%
upscaled_masks = da.from_zarr(Path(test_path).joinpath('0'))
print("upscaled mask shape: ", upscaled_masks.shape)
# Out:
# upscaled mask shape:  (1, 1, 965, 9252, 9241)
